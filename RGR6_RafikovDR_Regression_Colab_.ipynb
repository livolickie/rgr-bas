# %% [markdown]
# #Рафиков Данил ПИ-321 РГР Этап 6
# ##Задание 2

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

reg = linear_model.LinearRegression()
np.random.seed(19130156) #Указываем номер зачетки

A = []
B = []
T = []
N = 10_000
n = 1000


for i in range(n):
  t = time.time()
  x = np.random.uniform(low = 150, high=200, size=N)
  e = np.random.normal(loc = 0, scale = 10, size = N)
  y = -100 + x + e

  reg.fit(x.reshape(-1, 1), y.reshape(-1, 1))
  A.append(reg.intercept_[0])
  B.append(reg.coef_[0][0])
  T.append(time.time() - t)

# %%
plt.figure(figsize=(10, 6))
plt.hist(B, bins = 20, edgecolor = 'black', color = 'white')
plt.title('Histogram of B estimates')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(A, bins = 20, edgecolor = 'black', color = 'white')
plt.title('Histogram of A estimates')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(T, bins = 20, edgecolor = 'black', color = 'white')
plt.title('Histogram of T estimates')
plt.show()

# %%
min(T), np.median(T), max(T)
# Out:
# (0.0009837150573730469, 0.0011861324310302734, 0.003210306167602539)

# %%
plt.figure(figsize=(10, 4))
plt.plot(T, marker='.')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.hist(T[300:500], bins = 30, edgecolor = 'black', color='white')
plt.show()

# %%
len(T)
# Out:
# 1000

# %%
plt.figure(figsize=(10, 4))
plt.plot(T, marker='.')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(T[365:560], marker='.')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.hist(T[365:560], bins = 30, edgecolor = 'black', color='white')
plt.show()
